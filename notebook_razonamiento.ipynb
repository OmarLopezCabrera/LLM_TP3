# %% [markdown]
# # 🧠 Prueba del Chatbot Modular de Razonamiento Avanzado
# Este notebook permite hacer pruebas directas usando el motor de agentes.

# %%
from agent_module import query_razonamiento

# Ejemplo de pregunta combinada
pregunta = "¿Cuánta energía eléctrica (en kWh) consumen actualmente los entrenamientos de los grandes modelos de lenguaje (LLMs/IA)? ¿Cuánto se estima que consumirán en el futuro y qué impacto podría tener este consumo en términos de contaminación ambiental y demanda energética a nivel mundial?"

# Ejecutar el razonamiento
resultado = query_razonamiento(pregunta)

# Mostrar resultados
print("=== Respuesta Final ===")
print(resultado["answer"])
print("\n=== Tokens Utilizados ===")
print(resultado["tokens"])
print("\n=== Razonamiento Intermedio ===")
for fase, contenido in resultado["intermediate_steps"].items():
    print(f"--- {fase} ---")
    print(contenido)
# Out:
# === Respuesta Final ===
# Texto refinado:
#
# **Consumo de energía y contaminación asociada a los grandes modelos de lenguaje y inteligencia artificial**
#
# En los últimos años, hemos presenciado un aumento exponencial en el desarrollo y el uso de grandes modelos de lenguaje (LLM) y inteligencia artificial (IA). Sin embargo, este avance tecnológico tiene un costo oculto: el consumo de energía y la contaminación asociada a él.
#
# **Consumo de energía actual**
#
# ...

# %% [markdown]
# ## ✍️ Puedes modificar la pregunta aquí abajo para hacer más pruebas:

# %%
# Cambia la pregunta si quieres
nueva_pregunta = "¿Qué porcentaje del consumo de agua dulce mundial se destina a la producción de alimentos de origen animal y cómo cambiaría esta cifra si el 25% de la población adoptara dietas vegetarianas?"

nuevo_resultado = query_razonamiento(nueva_pregunta)

# Mostrar resultados
print("=== Respuesta Final ===")
print(resultado["answer"])
print("\n=== Tokens Utilizados ===")
print(resultado["tokens"])
print("\n=== Razonamiento Intermedio ===")
for fase, contenido in resultado["intermediate_steps"].items():
    print(f"--- {fase} ---")
    print(contenido)
# Out:
# === Respuesta Final ===
# Texto refinado:
#
# **Consumo de energía y contaminación asociada a los grandes modelos de lenguaje y inteligencia artificial**
#
# En los últimos años, hemos presenciado un aumento exponencial en el desarrollo y el uso de grandes modelos de lenguaje (LLM) y inteligencia artificial (IA). Sin embargo, este avance tecnológico tiene un costo oculto: el consumo de energía y la contaminación asociada a él.
#
# **Consumo de energía actual**
#
# ...
